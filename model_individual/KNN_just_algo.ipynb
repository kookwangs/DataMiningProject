# %%
# Import data

import pandas as pd
data = pd.read_csv("preprocessed_data.csv")
data
# Out:
#         age gender  height_cm  weight_kg  body_fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13315  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13316  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13317  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13318  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13319  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripforce  sit_and_bend_forward_cm  sit_ups_counts  broad_jump_cm  \
# ...

# %% [markdown]
# # **KNN Predict from just 1 attribute**

# %%
from collections import Counter
import math
import pandas as pd

def knn(data, query, k, distance_fn, choice_fn):
    neighbor_distances_and_indices = []
    
    # 3. For each example in the data
    for index, example in enumerate(data):
        # 3.1 Calculate the distance between the query example and the current
        # example from the data.
        
        print(example[:-1])
        distance = distance_fn(example[:-1], query)
        
        # 3.2 Add the distance and the index of the example to an ordered collection
        neighbor_distances_and_indices.append((distance, index))
    
    # 4. Sort the ordered collection of distances and indices from
    # smallest to largest (in ascending order) by the distances
    sorted_neighbor_distances_and_indices = sorted(neighbor_distances_and_indices)
    
    # 5. Pick the first K entries from the sorted collection
    k_nearest_distances_and_indices = sorted_neighbor_distances_and_indices[:k]
    
    # 6. Get the labels of the selected K entries
    k_nearest_labels = [data[i][-1] for distance, i in k_nearest_distances_and_indices]
    print("The k-nearest neighbor has these classes where k = ",k)
    print("\t\t",k_nearest_labels)
    print("Majority vote on them and get the result")
    # 7. If regression (choice_fn = mean), return the average of the K labels
    # 8. If classification (choice_fn = mode), return the mode of the K labels
    return k_nearest_distances_and_indices , choice_fn(k_nearest_labels)


def mean(labels):
    return sum(labels) / len(labels)

def mode(labels):
    return Counter(labels).most_common(1)[0][0]

def euclidean_distance(point1, point2):
    sum_squared_distance = 0
    for i in range(len(point1)):
        sum_squared_distance += math.pow(point1[i] - point2[i], 2)
    return math.sqrt(sum_squared_distance)

def main():
    data = pd.read_csv("preprocessed_data.csv")
    selected_column = "sit_and_bend_forward_cm"
    data1 = data[[selected_column,'class']]

    #data1 = data1.astype({'sepallength':'float','petallength':'float'})
    print("Preprocessed data: select only \"sit_and_bend_forward_cm\" and \"class\"")
    print(data1)

    data1 = data1.values.tolist()
    data1_predict = [9]
    print("Predict on the value ", data1_predict, " from ",selected_column)

    # Euclidean function

    print("Using Euclidean function")
    reg_k_nearest_neighbors, reg_prediction = knn(
        data1, data1_predict, k=7, distance_fn=euclidean_distance, choice_fn=mode
    )
    print("\t\toutput = ", reg_prediction)

if __name__ == '__main__':
    main()
# Out:
# Preprocessed data: select only "sit_and_bend_forward_cm" and "class"
#        sit_and_bend_forward_cm class
# 0                         18.4     C
# 1                         16.3     A
# 2                         12.0     C
# 3                         15.2     B
# 4                         27.1     B
# ...                        ...   ...
# 13315                     17.4     C
# 13316                      1.1     D
# 13317                     16.4     A
# 13318                      9.2     D
# 13319                      7.1     C
#
# [13320 rows x 2 columns]
# Predict on the value  [9]  from  sit_and_bend_forward_cm
# Using Euclidean function
# [18.4]
# [16.3]
# [12.0]
# [15.2]
# [27.1]
# [21.0]
# [0.8]
# [12.3]
# [18.6]
# [12.1]
# [16.0]
# [30.0]
# [13.1]
# [19.2]
# [7.2]
# [19.0]
# [22.9]
# [17.8]
# [15.1]
# [20.5]
# [10.7]
# [29.1]
# [19.7]
# [11.6]
# [27.5]
# [4.0]
# [8.1]
# [3.7]
# [8.1]
# [24.4]
# [26.4]
# [9.1]
# [23.0]
# [-2.0]
# [21.3]
# [12.1]
# [6.3]
# [18.4]
# [16.2]
# ...

# %% [markdown]
# # **Stupid testing of 1 attr**

# %%
##### test with stupid dataset eiei
stupid = [[1,"A"],[2,"A"],[3,"B"],[6,"C"],[7,"D"]]
data1_predict = [2.5]
print("Predict on the value ", data1_predict)

    # Euclidean function

print("Using Euclidean function")
reg_k_nearest_neighbors, reg_prediction = knn(
        stupid, data1_predict, k=3, distance_fn=euclidean_distance, choice_fn=mode
    )
print("\t\t", reg_k_nearest_neighbors)
print("\t\toutput = ", reg_prediction)
# Out:
# Predict on the value  [2.5]
# Using Euclidean function
# [1]
# [2]
# [3]
# [6]
# [7]
# The k-nearest neighbor has these classes where k =  3
# 		 ['A', 'B', 'A']
# Majority vote on them and get the result
# 		 [(0.5, 1), (0.5, 2), (1.5, 0)]
# 		output =  A

# %% [markdown]
# # **KNN Predict from just 3 attribute**

# %%
from collections import Counter
import math
import pandas as pd

def knn3(data, query, k, distance_fn, choice_fn):
    neighbor_distances_and_indices = []
    
    # 3. For each example in the data
    for index, example in enumerate(data):
        # 3.1 Calculate the distance between the query example and the current
        # example from the data.
        distance = distance_fn(example, query)
        
        # 3.2 Add the distance and the index of the example to an ordered collection
        neighbor_distances_and_indices.append((distance, index))
    
    # 4. Sort the ordered collection of distances and indices from
    # smallest to largest (in ascending order) by the distances
    sorted_neighbor_distances_and_indices = sorted(neighbor_distances_and_indices)
    
    # 5. Pick the first K entries from the sorted collection
    k_nearest_distances_and_indices = sorted_neighbor_distances_and_indices[:k]
    
    # 6. Get the labels of the selected K entries
    k_nearest_labels = [data[i][-1] for distance, i in k_nearest_distances_and_indices]
    print("The k-nearest neighbor has these classes where k = ",k)
    print("\t\t",k_nearest_labels)
    print("Majority vote on them and get the result")
    # 7. If regression (choice_fn = mean), return the average of the K labels
    # 8. If classification (choice_fn = mode), return the mode of the K labels
    return k_nearest_distances_and_indices , choice_fn(k_nearest_labels)

def mode(labels):
    return Counter(labels).most_common(1)[0][0]

def euclidean_distance_3(sample, target):
    sum_squared_distance = 0
    for i in range(3):
        sum_squared_distance += math.pow(sample[i] - target[i], 2)
    return math.sqrt(sum_squared_distance)

def main():
    data = pd.read_csv("preprocessed_data.csv")
    selected_column1 = "sit_and_bend_forward_cm"
    selected_column2 = "sit_ups_counts"
    selected_column3 = "broad_jump_cm"

    data1 = data[[selected_column1,selected_column2,selected_column3,'class']]
    print(data1)

    #data1 = data1.astype({'sepallength':'float','petallength':'float'})
    print("Preprocessed data: ")
    print(data1.dtypes)

    data1 = data1.values.tolist()
    data1_predict = [9,10,10]
    print("Predict on the value ", data1_predict)

    # Euclidean function

    print("Using Euclidean function")
    reg_k_nearest_neighbors, reg_prediction = knn3(
        data1, data1_predict, k=7, distance_fn=euclidean_distance_3, choice_fn=mode
    )
    print("\t\toutput = ", reg_prediction)

if __name__ == '__main__':
    main()
# Out:
#        sit_and_bend_forward_cm  sit_ups_counts  broad_jump_cm class
# 0                         18.4            60.0          217.0     C
# 1                         16.3            53.0          229.0     A
# 2                         12.0            49.0          181.0     C
# 3                         15.2            53.0          219.0     B
# 4                         27.1            45.0          217.0     B
# ...                        ...             ...            ...   ...
# 13315                     17.4            47.0          198.0     C
# 13316                      1.1            48.0          167.0     D
# 13317                     16.4            45.0          229.0     A
# 13318                      9.2             0.0           75.0     D
# 13319                      7.1            51.0          180.0     C
#
# [13320 rows x 4 columns]
# Preprocessed data:
# sit_and_bend_forward_cm    float64
# sit_ups_counts             float64
# ...

# %% [markdown]
# # **Stupid testing of 3 attr**

# %%
##### test with stupid dataset eiei
stupid2 = [[1,1,0,"A"],[2,0,1,"A"],[2,1,1,"B"],[5,6,7,"C"],[7,8,9,"D"]]
data1_predict = [1,1,1]
print("Predict on the value ", data1_predict)

    # Euclidean function

print("Using Euclidean function")
reg_k_nearest_neighbors, reg_prediction = knn3(
        stupid2, data1_predict, k=4, distance_fn=euclidean_distance_3, choice_fn=mode
    )
print("\t\t", reg_k_nearest_neighbors)
print("\t\toutput = ", reg_prediction)
# Out:
# Predict on the value  [1, 1, 1]
# Using Euclidean function
# The k-nearest neighbor has these classes where k =  4
# 		 ['A', 'B', 'A', 'C']
# Majority vote on them and get the result
# 		 [(1.0, 0), (1.0, 2), (1.4142135623730951, 1), (8.774964387392123, 3)]
# 		output =  A
